# %% [markdown]
# # Evaluate ensemble members
#
# The goal of this script is to identify ensemble members that meet specific ecological criteria

# %%
import pandas as pd
import numpy as np
import os
import esm_tools
pd.set_option('display.max_rows', 500) 
import shutil

# %%
# Path to where the prior ensemble run parameter files are stored
path_to_ensemble_param_files_root = '/glade/u/home/adamhb/ahb_params/fates_api_25/ensembles/'

# %%
def get_most_recent_file_in_dir(folder_path):

    # Get a list of all files in the folder
    files = os.listdir(folder_path)

    # Filter out only files (excluding subdirectories)
    files = [file for file in files if os.path.isfile(os.path.join(folder_path, file))]

    # Sort the files by creation time (most recent first)
    files.sort(key=lambda x: os.path.getctime(os.path.join(folder_path, x)), reverse=True)

    # Check if there are any files in the folder
    if files:
        most_recent_file = files[0]
        print(f"The most recently created file is: {most_recent_file}")
        return most_recent_file
    else:
        print("The folder is empty.")

# %% [markdown]
# ## Set up which files are being aggregated and evaluated

# %%
case_name_prefix = 'CZ2_equilibrium_101723_'
case_name_suffix = '_-17e2acb6a_FATES-8a054a12'
case_numbers = [1,2,3]

all_member_output_filename = 'all_member_output_CZ2_equilibrium_101723.csv'
successful_members_file_name = "successfull_members_CZ2_equilibrium_101723.csv"

# Path to put any processed output
processed_output_root = '/glade/scratch/adamhb/processed_output'

case_tags = [str(case_num).rjust(2, '0') for case_num in case_numbers]
print("Case Tags:")
print(case_tags)
print("\n")
folder_names = [case_name_prefix + case_tag + case_name_suffix for case_tag in case_tags]
folder_paths = [os.path.join(processed_output_root,folder_name) for folder_name in folder_names]

print("Folders:")
print(folder_paths)
print("\n")

print("Files")
[get_most_recent_file_in_dir(folder_path) for folder_path in folder_paths]
print("\n")

print("Full file paths:")
files = [get_most_recent_file_in_dir(folder_path) for folder_path in folder_paths]
full_file_paths = [os.path.join(folder_paths[i],files[i]) for i in range(len(files))]
print(full_file_paths)
# Out:
# Case Tags:
# ['01', '02', '03']
#
#
# Folders:
# ['/glade/scratch/adamhb/processed_output/CZ2_equilibrium_101723_01_-17e2acb6a_FATES-8a054a12', '/glade/scratch/adamhb/processed_output/CZ2_equilibrium_101723_02_-17e2acb6a_FATES-8a054a12', '/glade/scratch/adamhb/processed_output/CZ2_equilibrium_101723_03_-17e2acb6a_FATES-8a054a12']
#
#
# Files
# The most recently created file is: ensemble_output_CZ2_equilibrium_101723_01_-17e2acb6a_FATES-8a054a12_decadal_metrics.csv
# The most recently created file is: ensemble_output_CZ2_equilibrium_101723_02_-17e2acb6a_FATES-8a054a12_decadal_metrics.csv
# The most recently created file is: ensemble_output_CZ2_equilibrium_101723_03_-17e2acb6a_FATES-8a054a12_decadal_metrics.csv
#
#
# Full file paths:
# The most recently created file is: ensemble_output_CZ2_equilibrium_101723_01_-17e2acb6a_FATES-8a054a12_decadal_metrics.csv
# The most recently created file is: ensemble_output_CZ2_equilibrium_101723_02_-17e2acb6a_FATES-8a054a12_decadal_metrics.csv
# The most recently created file is: ensemble_output_CZ2_equilibrium_101723_03_-17e2acb6a_FATES-8a054a12_decadal_metrics.csv
# ['/glade/scratch/adamhb/processed_output/CZ2_equilibrium_101723_01_-17e2acb6a_FATES-8a054a12/ensemble_output_CZ2_equilibrium_101723_01_-17e2acb6a_FATES-8a054a12_decadal_metrics.csv', '/glade/scratch/adamhb/processed_output/CZ2_equilibrium_101723_02_-17e2acb6a_FATES-8a054a12/ensemble_output_CZ2_equilibrium_101723_02_-17e2acb6a_FATES-8a054a12_decadal_metrics.csv', '/glade/scratch/adamhb/processed_output/CZ2_equilibrium_101723_03_-17e2acb6a_FATES-8a054a12/ensemble_output_CZ2_equilibrium_101723_03_-17e2acb6a_FATES-8a054a12_decadal_metrics.csv']

# %% [markdown]
# ## Get all data into on dataframe

# %%
df = pd.DataFrame()
i = 0
for f in full_file_paths:
    df_tmp = pd.read_csv(f)
    df_tmp = df_tmp.drop(df_tmp.columns[0], axis=1)
    df_tmp['case_tag'] = case_tags[i]
    df = pd.concat([df,df_tmp],axis = 0)
    i = i + 1

# %%
df.to_csv(processed_output_root + "/" + "with_fire_metrics_" + all_member_output_filename)

# %%
cols = ["case_tag","inst","BA","BA_pine","BA_cedar","BA_fir","BA_shrub","BA_oak",
 "AGB","TreeStemD","ResproutD_oak","ResproutD_shrub","ShannonE","NPP","FailedPFTs",
        "Pct_shrub_cover_canopy","Pct_shrub_cover","Combustible_fuel","Burned_area","Pct_high_severity_1700","Pct_high_severity_3500"]

# %%
df = df[cols]

# %%
df[cols]
# Out:
#   case_tag  inst         BA    BA_pine   BA_cedar    BA_fir   BA_shrub  \
# 0       01     3  23.958220   0.295358  15.511509  0.070217   4.297803
# 1       01    11  24.391005   0.074526  16.717539  0.985907   6.075087
# 2       01    14  18.205610   0.074029   5.964147  0.303579   0.535164
# 3       01    19  16.377903   0.001866   4.996992  0.176686   2.995747
# 4       01    21  21.933979   6.421227   9.719576  1.753197   0.242180
# 5       01    22  23.984100   0.574372   8.991769  8.577020   0.400098
# 6       01    23  22.735706   9.061029   0.953378  0.101761  12.590818
# 7       01    24  17.974762   0.010423   1.317839  0.856292   0.847386
# 0       02     7  24.086369  15.361878   0.283073  0.202542   4.126918
# 1       02    15  42.443077   4.479413  36.863630  0.308961   0.789293
# 2       02    31  30.807259   0.782406  15.214353  0.043552  14.655736
# 0       03     7   8.791829   0.114385   0.225538  0.299844   1.070565
# 1       03     8  23.683720   1.375601  12.954458  0.247357   8.354259
# 2       03    12  17.374847   0.455095   9.355842  0.235283   6.900225
# 3       03    23  24.232082  18.412819   0.448918  0.082926   5.162600
#
#       BA_oak        AGB   TreeStemD  ...  ResproutD_shrub  ShannonE       NPP  \
# 0   3.783331   5.462409  275.145955  ...         0.000000  0.591781  0.651599
# 1   0.537947   4.456143  549.873896  ...         0.098707  0.519827  0.833952
# 2  11.328691   4.697561  800.293684  ...         0.000000  0.531310  0.808131
# 3   8.206612   3.789244  264.937449  ...         0.000000  0.664239  0.731382
# 4   3.797798   5.086062  379.617140  ...         0.000000  0.792590  0.575475
# 5   5.440842   6.969836  385.876298  ...         0.000000  0.764074  0.599534
# 6   0.028721   3.792508  109.073743  ...         0.223199  0.534068  0.745532
# 7  14.942822   6.631061  316.578262  ...         0.000000  0.396716  0.887236
# 0   4.111957   5.975501  649.154708  ...         0.000000  0.610958  0.818854
# 1   0.001785  12.059237  483.535454  ...         0.000000  0.292087  0.816989
# 2   0.111213   5.368556  324.691236  ...         0.000000  0.512421  1.095062
# 0   7.081497   2.188334  135.795139  ...         0.000979  0.432654  0.595018
# 1   0.752044   3.173323  903.128609  ...         0.000000  0.633800  0.900777
# 2   0.428402   3.009277  262.839906  ...         0.000000  0.587176  0.719558
# 3   0.124820   4.061810  244.541578  ...         0.000000  0.409187  1.014589
#
#    FailedPFTs  Pct_shrub_cover_canopy  Pct_shrub_cover  Combustible_fuel  \
# 0           1                0.106477         0.189698          0.556339
# 1           1                0.136743         0.438737          0.834401
# 2           1                0.000065         0.043620          0.853940
# 3           1                0.097210         0.172463          1.436287
# 4           0                0.020254         0.022734          0.426593
# 5           0                0.015976         0.017849          0.719824
# 6           1                0.409533         0.527732          0.778930
# 7           1                0.011766         0.041302          0.701013
# 0           0                0.233132         0.314411          1.912418
# 1           1                0.019316         0.038751          1.349837
# 2           1                0.412073         0.526991          0.713635
# 0           0                0.031456         0.068801          0.902176
# 1           0                0.263906         0.860462          0.738459
# 2           0                0.495709         0.497644          1.254374
# 3           1                0.117737         0.416432          0.913806
#
#    Burned_area  Pct_high_severity_1700  Pct_high_severity_3500
# 0        0.013                0.000000                0.000000
# 1        0.039                4.054054                0.000000
# 2        0.026               28.813559                1.694915
# 3        0.016               50.434783               10.434783
# 4        0.043                0.000000                0.000000
# 5        0.022                0.000000                0.000000
# 6        0.085                2.298851                0.000000
# 7        0.016               36.842105                1.754386
# 0        0.021               48.101266               11.392405
# 1        0.008               25.609756                0.000000
# 2        0.009                9.722222                0.000000
# 0        0.037               35.454545                2.727273
# 1        0.055                0.000000                0.000000
# 2        0.028               36.458333                7.291667
# 3        0.066               12.500000                0.000000
#
# [15 rows x 21 columns]

# %%
list(df.columns)
# Out:
# ['BA',
#  'AGB',
#  'TreeStemD',
#  'ResproutD_oak',
#  'ResproutD_shrub',
#  'ShannonE',
#  'NPP',
#  'FailedPFTs',
#  'Pct_shrub_cover_canopy',
#  'Pct_shrub_cover',
#  'Combustible_fuel',
#  'Burned_area',
#  'Pct_high_severity_1700',
#  'Pct_high_severity_3500',
#  'BA_pine',
#  'BA_cedar',
#  'BA_fir',
#  'BA_shrub',
#  'BA_oak',
#  'inst',
#  'fates_recruit_seed_alloc_mature_1',
#  'fates_recruit_seed_alloc_mature_2',
#  'fates_recruit_seed_alloc_mature_3',
#  'fates_recruit_seed_alloc_mature_4',
#  'fates_recruit_seed_alloc_mature_5',
#  'fates_recruit_seed_dbh_repro_threshold_1',
#  'fates_recruit_seed_dbh_repro_threshold_2',
#  'fates_recruit_seed_dbh_repro_threshold_3',
#  'fates_recruit_seed_dbh_repro_threshold_5',
#  'fates_fire_alpha_SH_1',
#  'fates_fire_alpha_SH_2',
#  'fates_fire_alpha_SH_3',
#  'fates_fire_alpha_SH_4',
#  'fates_fire_alpha_SH_5',
#  'fates_fire_bark_scaler_1',
#  'fates_fire_bark_scaler_2',
#  'fates_fire_bark_scaler_3',
#  'fates_fire_bark_scaler_4',
#  'fates_fire_bark_scaler_5',
#  'fates_fire_crown_kill_1',
#  'fates_fire_crown_kill_2',
#  'fates_fire_crown_kill_3',
#  'fates_fire_crown_kill_4',
#  'fates_fire_crown_kill_5',
#  'fates_fire_drying_ratio_0',
#  'fates_fire_nignitions_0',
#  'fates_fire_threshold_0',
#  'fates_mort_bmort_1',
#  'fates_mort_bmort_2',
#  'fates_mort_bmort_3',
#  'fates_mort_bmort_4',
#  'fates_mort_bmort_5',
#  'fates_leaf_slatop_1',
#  'fates_leaf_slatop_2',
#  'fates_leaf_slatop_3',
#  'fates_leaf_slatop_4',
#  'fates_leaf_slatop_5',
#  'fates_leaf_slamax_0',
#  'fates_leaf_vcmax25top_1',
#  'fates_leaf_vcmax25top_2',
#  'fates_leaf_vcmax25top_3',
#  'fates_leaf_vcmax25top_4',
#  'fates_leaf_vcmax25top_5',
#  'fates_mort_scalar_cstarvation_1',
#  'fates_mort_scalar_cstarvation_2',
#  'fates_mort_scalar_cstarvation_3',
#  'fates_mort_scalar_cstarvation_4',
#  'fates_mort_scalar_cstarvation_5',
#  'fates_fire_frac_resprout_4',
#  'fates_fire_frac_resprout_5',
#  'fates_frag_seed_decay_rate_1',
#  'fates_frag_seed_decay_rate_2',
#  'fates_frag_seed_decay_rate_3',
#  'fates_frag_seed_decay_rate_4',
#  'fates_frag_seed_decay_rate_5',
#  'fates_recruit_seed_germination_rate_1',
#  'fates_recruit_seed_germination_rate_2',
#  'fates_recruit_seed_germination_rate_3',
#  'fates_recruit_seed_germination_rate_4',
#  'fates_recruit_seed_germination_rate_5',
#  'fates_disturbance_germ_4',
#  'fates_turnover_branch_1',
#  'fates_turnover_branch_2',
#  'fates_turnover_branch_3',
#  'fates_turnover_branch_4',
#  'fates_turnover_branch_5',
#  'fates_turnover_leaf_1',
#  'fates_turnover_leaf_2',
#  'fates_turnover_leaf_3',
#  'fates_turnover_leaf_4',
#  'fates_turnover_leaf_5',
#  'fates_nonhydro_smpsc_1',
#  'fates_nonhydro_smpsc_2',
#  'fates_nonhydro_smpsc_3',
#  'fates_nonhydro_smpsc_4',
#  'fates_nonhydro_smpsc_5',
#  'fates_mort_hf_sm_threshold_0',
#  'fates_recruit_inter_patch_disp_frac_0',
#  'fates_frag_maxdecomp_0',
#  'fates_alloc_storage_cushion_5',
#  'fates_grperc_4',
#  'fates_stoich_nitr_1',
#  'fates_stoich_nitr_2',
#  'fates_stoich_nitr_3',
#  'fates_stoich_nitr_4',
#  'fates_stoich_nitr_5',
#  'fates_mort_ip_size_senescence_4',
#  'fates_mort_ip_age_senescence_4',
#  'fates_allom_d2ca_coefficient_max_1',
#  'fates_allom_d2ca_coefficient_max_2',
#  'fates_allom_d2ca_coefficient_max_3',
#  'fates_allom_d2ca_coefficient_max_4',
#  'fates_allom_d2ca_coefficient_max_5',
#  'fates_allom_d2ca_coefficient_min_0',
#  'fates_allom_agb1_1',
#  'fates_allom_agb1_2',
#  'fates_allom_agb1_3',
#  'fates_allom_agb1_5',
#  'case_tag']

# %% [markdown]
# ## Filter to ensemble members that meet ecological criteria
#
# CZ2 Pre-Euro-American Management--criteria for analyzing fire regimes
#
# 1. There are 0 failing pfts (all pfts have above at least 0.1 m2 ha-1 of basal area)
# 2. Shrub percent cover is > 1% and < 50%

# %%
CZ2_analyze_fire_regime_filter = (df['FailedPFTs'] < 2) & (df['Pct_shrub_cover'] > 0.01) & (df['Pct_shrub_cover_canopy'] < 0.5)
CZ2_analyze_fire_regime = df.loc[CZ2_analyze_fire_regime_filter].sort_values("ShannonE",ascending = False)
CZ2_analyze_fire_regime.shape


#Take just the top 108 members to run a 3-node simulation to equilibrium
#CZ2_analyze_fire_regime = CZ2_analyze_fire_regime[:108]

CZ2_analyze_fire_regime.to_csv(os.path.join(processed_output_root,successfull_members_file_name))
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In [49], line 9
#       3 CZ2_analyze_fire_regime.shape
#       6 #Take just the top 108 members to run a 3-node simulation to equilibrium
#       7 #CZ2_analyze_fire_regime = CZ2_analyze_fire_regime[:108]
# ----> 9 CZ2_analyze_fire_regime.to_csv(os.path.join(processed_output_root,successfull_members_file_name))
#
# NameError: name 'successfull_members_file_name' is not defined

# %%
CZ2_analyze_fire_regime.to_csv("/glade/scratch/adamhb/processed_output/successfull_members_CZ2_equilibrium_101723.csv")

# %%
print(list(CZ2_analyze_fire_regime["inst"]))
# Out:
# [21, 22, 19, 8, 7, 3, 12, 23, 14, 11, 31, 7, 23, 24, 15]

# %% [markdown]
# ## Prepare passing parameterizations for next simulation

# %%
new_case_tags
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In [85], line 1
# ----> 1 new_case_tags
#
# NameError: name 'new_case_tags' is not defined

# %%
def aggregate_passing_paramsets(pass_case_tags,passing_inst_tags,n_new_cases,n_inst_per_case,new_subdirs_prefix,
                                path_to_ensemble_param_files_root,old_param_subdir_prefix,new_param_file_base_name):
    
    
    for n in range(n_new_cases):
        new_param_subdir_suffix = str(n+1).rjust(2, '0')
        
        new_param_subdir = os.path.join(path_to_ensemble_param_files_root,new_subdirs_prefix) + "_" + new_param_subdir_suffix
        os.makedirs(new_param_subdir,exist_ok=True)
    
    tmp_inst = 0
    for case_tag,inst_tag in zip(pass_case_tags,passing_inst_tags):
        
        tmp_inst = tmp_inst + 1
        
        param_files_subdir = old_param_subdir_prefix + "_" + case_tag
        
        # Get tag
        inst_tag_with_leading_zeroes = str(inst_tag).rjust(4, '0')
    
        # Get param file with inst tag
        ref_nc_file = esm_tools.find_files_with_substring(directory=os.path.join(path_to_ensemble_param_files_root,
                                                                       param_files_subdir),
                                                substring=inst_tag_with_leading_zeroes)

        # Get full path of originl param file
        ref_nc_file_full_path = os.path.join(path_to_ensemble_param_files_root,param_files_subdir,ref_nc_file[0])

        print("originl_file:",ref_nc_file_full_path)

        
        #Copy to new folder
        os.makedirs("tmp",exist_ok=True)
        
        new_tag = str(tmp_inst).rjust(4, '0')
    
        new_name = new_param_file_base_name + "_" + new_tag + ".nc"

        dst_file = os.path.join("tmp",new_name)
        
        print("tmp file:",dst_file)
        print("\n")

        shutil.copy(ref_nc_file_full_path,dst_file)
        
        
        # allocate across new cases
        new_case_tags = [str(case_tag+1).rjust(2, '0') for case_tag in range(n_new_cases)]
      
        
    for i,new_case_tag in enumerate(new_case_tags):
            
            new_param_subdir = os.path.join(path_to_ensemble_param_files_root,new_subdirs_prefix) + "_" + new_case_tag
            
            tmp_inst = i * n_inst_per_case
            
            for i in range(n_inst_per_case):
                
                tmp_inst = tmp_inst + 1
                
                tmp_inst_tag = str(tmp_inst).rjust(4, '0')
                
                 # Get param file with inst tag
                ref_nc_file = esm_tools.find_files_with_substring(directory="tmp",
                                                substring=tmp_inst_tag)

                # Get full path of originl param file
                ref_nc_file_full_path = os.path.join("tmp",ref_nc_file[0])
                
                print("tmp_file:",ref_nc_file_full_path)
                
                new_tag = str(i + 1).rjust(4, '0')
                new_name = new_param_file_base_name + "_" + new_tag + ".nc"
                dst_file = os.path.join(path_to_ensemble_param_files_root,new_param_subdir,new_name)
                
                shutil.copy(ref_nc_file_full_path,dst_file)
                
                print("destination:",dst_file)

# %%
aggregate_passing_paramsets(pass_case_tags = CZ2_analyze_fire_regime['case_tag'],
                            passing_inst_tags = CZ2_analyze_fire_regime['inst'],
                            n_new_cases = 3,
                            n_inst_per_case = 36,
                            new_subdirs_prefix = "CZ2_equilibrium_101723",
                            path_to_ensemble_param_files_root = path_to_ensemble_param_files_root,
                            old_param_subdir_prefix = 'ca_5pfts_20cases_4320inst_101223',
                            new_param_file_base_name = 'CZ2_equilibrium_101723')
# Out:
# originl_file: /glade/u/home/adamhb/ahb_params/fates_api_25/ensembles/ca_5pfts_20cases_4320inst_101223_04/ca_5pfts_100523_0036.nc
# tmp file: tmp/CZ2_equilibrium_101723_0001.nc
#
#
# originl_file: /glade/u/home/adamhb/ahb_params/fates_api_25/ensembles/ca_5pfts_20cases_4320inst_101223_13/ca_5pfts_100523_0134.nc
# tmp file: tmp/CZ2_equilibrium_101723_0002.nc
#
#
# originl_file: /glade/u/home/adamhb/ahb_params/fates_api_25/ensembles/ca_5pfts_20cases_4320inst_101223_03/ca_5pfts_100523_0121.nc
# tmp file: tmp/CZ2_equilibrium_101723_0003.nc
#
#
# originl_file: /glade/u/home/adamhb/ahb_params/fates_api_25/ensembles/ca_5pfts_20cases_4320inst_101223_05/ca_5pfts_100523_0092.nc
# tmp file: tmp/CZ2_equilibrium_101723_0004.nc
#
#
# originl_file: /glade/u/home/adamhb/ahb_params/fates_api_25/ensembles/ca_5pfts_20cases_4320inst_101223_04/ca_5pfts_100523_0005.nc
# tmp file: tmp/CZ2_equilibrium_101723_0005.nc
#
#
# originl_file: /glade/u/home/adamhb/ahb_params/fates_api_25/ensembles/ca_5pfts_20cases_4320inst_101223_07/ca_5pfts_100523_0060.nc
# tmp file: tmp/CZ2_equilibrium_101723_0006.nc
#
#
# originl_file: /glade/u/home/adamhb/ahb_params/fates_api_25/ensembles/ca_5pfts_20cases_4320inst_101223_15/ca_5pfts_100523_0021.nc
# tmp file: tmp/CZ2_equilibrium_101723_0007.nc
#
#
# originl_file: /glade/u/home/adamhb/ahb_params/fates_api_25/ensembles/ca_5pfts_20cases_4320inst_101223_20/ca_5pfts_100523_0147.nc
# tmp file: tmp/CZ2_equilibrium_101723_0008.nc
#
#
# originl_file: /glade/u/home/adamhb/ahb_params/fates_api_25/ensembles/ca_5pfts_20cases_4320inst_101223_17/ca_5pfts_100523_0112.nc
# tmp file: tmp/CZ2_equilibrium_101723_0009.nc
#
#
# originl_file: /glade/u/home/adamhb/ahb_params/fates_api_25/ensembles/ca_5pfts_20cases_4320inst_101223_07/ca_5pfts_100523_0040.nc
# tmp file: tmp/CZ2_equilibrium_101723_0010.nc
#
#
# originl_file: /glade/u/home/adamhb/ahb_params/fates_api_25/ensembles/ca_5pfts_20cases_4320inst_101223_18/ca_5pfts_100523_0088.nc
# tmp file: tmp/CZ2_equilibrium_101723_0011.nc
#
#
# originl_file: /glade/u/home/adamhb/ahb_params/fates_api_25/ensembles/ca_5pfts_20cases_4320inst_101223_19/ca_5pfts_100523_0127.nc
# tmp file: tmp/CZ2_equilibrium_101723_0012.nc
#
#
# originl_file: /glade/u/home/adamhb/ahb_params/fates_api_25/ensembles/ca_5pfts_20cases_4320inst_101223_07/ca_5pfts_100523_0168.nc
# tmp file: tmp/CZ2_equilibrium_101723_0013.nc
#
#
# originl_file: /glade/u/home/adamhb/ahb_params/fates_api_25/ensembles/ca_5pfts_20cases_4320inst_101223_17/ca_5pfts_100523_0212.nc
# tmp file: tmp/CZ2_equilibrium_101723_0014.nc
#
#
# originl_file: /glade/u/home/adamhb/ahb_params/fates_api_25/ensembles/ca_5pfts_20cases_4320inst_101223_15/ca_5pfts_100523_0036.nc
# tmp file: tmp/CZ2_equilibrium_101723_0015.nc
#
#
# originl_file: /glade/u/home/adamhb/ahb_params/fates_api_25/ensembles/ca_5pfts_20cases_4320inst_101223_16/ca_5pfts_100523_0038.nc
# tmp file: tmp/CZ2_equilibrium_101723_0016.nc
#
#
# originl_file: /glade/u/home/adamhb/ahb_params/fates_api_25/ensembles/ca_5pfts_20cases_4320inst_101223_06/ca_5pfts_100523_0046.nc
# tmp file: tmp/CZ2_equilibrium_101723_0017.nc
#
#
# originl_file: /glade/u/home/adamhb/ahb_params/fates_api_25/ensembles/ca_5pfts_20cases_4320inst_101223_06/ca_5pfts_100523_0210.nc
# tmp file: tmp/CZ2_equilibrium_101723_0018.nc
#
#
# originl_file: /glade/u/home/adamhb/ahb_params/fates_api_25/ensembles/ca_5pfts_20cases_4320inst_101223_13/ca_5pfts_100523_0037.nc
# tmp file: tmp/CZ2_equilibrium_101723_0019.nc
#
#
# originl_file: /glade/u/home/adamhb/ahb_params/fates_api_25/ensembles/ca_5pfts_20cases_4320inst_101223_16/ca_5pfts_100523_0105.nc
# tmp file: tmp/CZ2_equilibrium_101723_0020.nc
#
#
# originl_file: /glade/u/home/adamhb/ahb_params/fates_api_25/ensembles/ca_5pfts_20cases_4320inst_101223_19/ca_5pfts_100523_0109.nc
# tmp file: tmp/CZ2_equilibrium_101723_0021.nc
#
#
# originl_file: /glade/u/home/adamhb/ahb_params/fates_api_25/ensembles/ca_5pfts_20cases_4320inst_101223_16/ca_5pfts_100523_0061.nc
# tmp file: tmp/CZ2_equilibrium_101723_0022.nc
#
#
# originl_file: /glade/u/home/adamhb/ahb_params/fates_api_25/ensembles/ca_5pfts_20cases_4320inst_101223_16/ca_5pfts_100523_0026.nc
# tmp file: tmp/CZ2_equilibrium_101723_0023.nc
#
#
# originl_file: /glade/u/home/adamhb/ahb_params/fates_api_25/ensembles/ca_5pfts_20cases_4320inst_101223_18/ca_5pfts_100523_0144.nc
# tmp file: tmp/CZ2_equilibrium_101723_0024.nc
#
#
# originl_file: /glade/u/home/adamhb/ahb_params/fates_api_25/ensembles/ca_5pfts_20cases_4320inst_101223_12/ca_5pfts_100523_0095.nc
# tmp file: tmp/CZ2_equilibrium_101723_0025.nc
#
#
# originl_file: /glade/u/home/adamhb/ahb_params/fates_api_25/ensembles/ca_5pfts_20cases_4320inst_101223_06/ca_5pfts_100523_0181.nc
# tmp file: tmp/CZ2_equilibrium_101723_0026.nc
#
#
# originl_file: /glade/u/home/adamhb/ahb_params/fates_api_25/ensembles/ca_5pfts_20cases_4320inst_101223_20/ca_5pfts_100523_0110.nc
# tmp file: tmp/CZ2_equilibrium_101723_0027.nc
#
#
# originl_file: /glade/u/home/adamhb/ahb_params/fates_api_25/ensembles/ca_5pfts_20cases_4320inst_101223_07/ca_5pfts_100523_0158.nc
# tmp file: tmp/CZ2_equilibrium_101723_0028.nc
#
#
# originl_file: /glade/u/home/adamhb/ahb_params/fates_api_25/ensembles/ca_5pfts_20cases_4320inst_101223_19/ca_5pfts_100523_0216.nc
# tmp file: tmp/CZ2_equilibrium_101723_0029.nc
#
#
# originl_file: /glade/u/home/adamhb/ahb_params/fates_api_25/ensembles/ca_5pfts_20cases_4320inst_101223_17/ca_5pfts_100523_0118.nc
# tmp file: tmp/CZ2_equilibrium_101723_0030.nc
#
#
# originl_file: /glade/u/home/adamhb/ahb_params/fates_api_25/ensembles/ca_5pfts_20cases_4320inst_101223_20/ca_5pfts_100523_0198.nc
# tmp file: tmp/CZ2_equilibrium_101723_0031.nc
#
#
# originl_file: /glade/u/home/adamhb/ahb_params/fates_api_25/ensembles/ca_5pfts_20cases_4320inst_101223_19/ca_5pfts_100523_0130.nc
# tmp file: tmp/CZ2_equilibrium_101723_0032.nc
#
#
# originl_file: /glade/u/home/adamhb/ahb_params/fates_api_25/ensembles/ca_5pfts_20cases_4320inst_101223_06/ca_5pfts_100523_0142.nc
# tmp file: tmp/CZ2_equilibrium_101723_0033.nc
#
#
# originl_file: /glade/u/home/adamhb/ahb_params/fates_api_25/ensembles/ca_5pfts_20cases_4320inst_101223_17/ca_5pfts_100523_0008.nc
# tmp file: tmp/CZ2_equilibrium_101723_0034.nc
#
#
# originl_file: /glade/u/home/adamhb/ahb_params/fates_api_25/ensembles/ca_5pfts_20cases_4320inst_101223_17/ca_5pfts_100523_0168.nc
# tmp file: tmp/CZ2_equilibrium_101723_0035.nc
#
#
# originl_file: /glade/u/home/adamhb/ahb_params/fates_api_25/ensembles/ca_5pfts_20cases_4320inst_101223_08/ca_5pfts_100523_0164.nc
# tmp file: tmp/CZ2_equilibrium_101723_0036.nc
#
#
# originl_file: /glade/u/home/adamhb/ahb_params/fates_api_25/ensembles/ca_5pfts_20cases_4320inst_101223_07/ca_5pfts_100523_0180.nc
# tmp file: tmp/CZ2_equilibrium_101723_0037.nc
#
#
# originl_file: /glade/u/home/adamhb/ahb_params/fates_api_25/ensembles/ca_5pfts_20cases_4320inst_101223_16/ca_5pfts_100523_0186.nc
# tmp file: tmp/CZ2_equilibrium_101723_0038.nc
#
#
# originl_file: /glade/u/home/adamhb/ahb_params/fates_api_25/ensembles/ca_5pfts_20cases_4320inst_101223_20/ca_5pfts_100523_0078.nc
# tmp file: tmp/CZ2_equilibrium_101723_0039.nc
#
#
# originl_file: /glade/u/home/adamhb/ahb_params/fates_api_25/ensembles/ca_5pfts_20cases_4320inst_101223_07/ca_5pfts_100523_0065.nc
# tmp file: tmp/CZ2_equilibrium_101723_0040.nc
#
#
# originl_file: /glade/u/home/adamhb/ahb_params/fates_api_25/ensembles/ca_5pfts_20cases_4320inst_101223_12/ca_5pfts_100523_0154.nc
# tmp file: tmp/CZ2_equilibrium_101723_0041.nc
#
#
# originl_file: /glade/u/home/adamhb/ahb_params/fates_api_25/ensembles/ca_5pfts_20cases_4320inst_101223_03/ca_5pfts_100523_0204.nc
# tmp file: tmp/CZ2_equilibrium_101723_0042.nc
#
#
# originl_file: /glade/u/home/adamhb/ahb_params/fates_api_25/ensembles/ca_5pfts_20cases_4320inst_101223_07/ca_5pfts_100523_0071.nc
# tmp file: tmp/CZ2_equilibrium_101723_0043.nc
#
#
# originl_file: /glade/u/home/adamhb/ahb_params/fates_api_25/ensembles/ca_5pfts_20cases_4320inst_101223_20/ca_5pfts_100523_0127.nc
# tmp file: tmp/CZ2_equilibrium_101723_0044.nc
#
#
# originl_file: /glade/u/home/adamhb/ahb_params/fates_api_25/ensembles/ca_5pfts_20cases_4320inst_101223_18/ca_5pfts_100523_0014.nc
# tmp file: tmp/CZ2_equilibrium_101723_0045.nc
#
#
# originl_file: /glade/u/home/adamhb/ahb_params/fates_api_25/ensembles/ca_5pfts_20cases_4320inst_101223_13/ca_5pfts_100523_0045.nc
# tmp file: tmp/CZ2_equilibrium_101723_0046.nc
#
#
# originl_file: /glade/u/home/adamhb/ahb_params/fates_api_25/ensembles/ca_5pfts_20cases_4320inst_101223_15/ca_5pfts_100523_0169.nc
# tmp file: tmp/CZ2_equilibrium_101723_0047.nc
#
#
# originl_file: /glade/u/home/adamhb/ahb_params/fates_api_25/ensembles/ca_5pfts_20cases_4320inst_101223_20/ca_5pfts_100523_0216.nc
# tmp file: tmp/CZ2_equilibrium_101723_0048.nc
#
#
# originl_file: /glade/u/home/adamhb/ahb_params/fates_api_25/ensembles/ca_5pfts_20cases_4320inst_101223_08/ca_5pfts_100523_0103.nc
# tmp file: tmp/CZ2_equilibrium_101723_0049.nc
#
#
# originl_file: /glade/u/home/adamhb/ahb_params/fates_api_25/ensembles/ca_5pfts_20cases_4320inst_101223_08/ca_5pfts_100523_0101.nc
# tmp file: tmp/CZ2_equilibrium_101723_0050.nc
#
#
# originl_file: /glade/u/home/adamhb/ahb_params/fates_api_25/ensembles/ca_5pfts_20cases_4320inst_101223_06/ca_5pfts_100523_0058.nc
# tmp file: tmp/CZ2_equilibrium_101723_0051.nc
#
#
# originl_file: /glade/u/home/adamhb/ahb_params/fates_api_25/ensembles/ca_5pfts_20cases_4320inst_101223_20/ca_5pfts_100523_0148.nc
# tmp file: tmp/CZ2_equilibrium_101723_0052.nc
#
#
# originl_file: /glade/u/home/adamhb/ahb_params/fates_api_25/ensembles/ca_5pfts_20cases_4320inst_101223_16/ca_5pfts_100523_0072.nc
# tmp file: tmp/CZ2_equilibrium_101723_0053.nc
#
#
# originl_file: /glade/u/home/adamhb/ahb_params/fates_api_25/ensembles/ca_5pfts_20cases_4320inst_101223_19/ca_5pfts_100523_0195.nc
# tmp file: tmp/CZ2_equilibrium_101723_0054.nc
#
#
# originl_file: /glade/u/home/adamhb/ahb_params/fates_api_25/ensembles/ca_5pfts_20cases_4320inst_101223_06/ca_5pfts_100523_0054.nc
# tmp file: tmp/CZ2_equilibrium_101723_0055.nc
#
#
# originl_file: /glade/u/home/adamhb/ahb_params/fates_api_25/ensembles/ca_5pfts_20cases_4320inst_101223_03/ca_5pfts_100523_0179.nc
# tmp file: tmp/CZ2_equilibrium_101723_0056.nc
#
#
# originl_file: /glade/u/home/adamhb/ahb_params/fates_api_25/ensembles/ca_5pfts_20cases_4320inst_101223_15/ca_5pfts_100523_0056.nc
# tmp file: tmp/CZ2_equilibrium_101723_0057.nc
#
#
# originl_file: /glade/u/home/adamhb/ahb_params/fates_api_25/ensembles/ca_5pfts_20cases_4320inst_101223_07/ca_5pfts_100523_0215.nc
# tmp file: tmp/CZ2_equilibrium_101723_0058.nc
#
#
# originl_file: /glade/u/home/adamhb/ahb_params/fates_api_25/ensembles/ca_5pfts_20cases_4320inst_101223_19/ca_5pfts_100523_0214.nc
# tmp file: tmp/CZ2_equilibrium_101723_0059.nc
#
#
# originl_file: /glade/u/home/adamhb/ahb_params/fates_api_25/ensembles/ca_5pfts_20cases_4320inst_101223_04/ca_5pfts_100523_0203.nc
# tmp file: tmp/CZ2_equilibrium_101723_0060.nc
#
#
# originl_file: /glade/u/home/adamhb/ahb_params/fates_api_25/ensembles/ca_5pfts_20cases_4320inst_101223_18/ca_5pfts_100523_0140.nc
# tmp file: tmp/CZ2_equilibrium_101723_0061.nc
#
#
# originl_file: /glade/u/home/adamhb/ahb_params/fates_api_25/ensembles/ca_5pfts_20cases_4320inst_101223_20/ca_5pfts_100523_0056.nc
# tmp file: tmp/CZ2_equilibrium_101723_0062.nc
#
#
# originl_file: /glade/u/home/adamhb/ahb_params/fates_api_25/ensembles/ca_5pfts_20cases_4320inst_101223_15/ca_5pfts_100523_0178.nc
# tmp file: tmp/CZ2_equilibrium_101723_0063.nc
#
#
# originl_file: /glade/u/home/adamhb/ahb_params/fates_api_25/ensembles/ca_5pfts_20cases_4320inst_101223_16/ca_5pfts_100523_0181.nc
# tmp file: tmp/CZ2_equilibrium_101723_0064.nc
#
#
# originl_file: /glade/u/home/adamhb/ahb_params/fates_api_25/ensembles/ca_5pfts_20cases_4320inst_101223_06/ca_5pfts_100523_0121.nc
# tmp file: tmp/CZ2_equilibrium_101723_0065.nc
#
#
# originl_file: /glade/u/home/adamhb/ahb_params/fates_api_25/ensembles/ca_5pfts_20cases_4320inst_101223_17/ca_5pfts_100523_0057.nc
# tmp file: tmp/CZ2_equilibrium_101723_0066.nc
#
#
# originl_file: /glade/u/home/adamhb/ahb_params/fates_api_25/ensembles/ca_5pfts_20cases_4320inst_101223_15/ca_5pfts_100523_0087.nc
# tmp file: tmp/CZ2_equilibrium_101723_0067.nc
#
#
# originl_file: /glade/u/home/adamhb/ahb_params/fates_api_25/ensembles/ca_5pfts_20cases_4320inst_101223_04/ca_5pfts_100523_0159.nc
# tmp file: tmp/CZ2_equilibrium_101723_0068.nc
#
#
# originl_file: /glade/u/home/adamhb/ahb_params/fates_api_25/ensembles/ca_5pfts_20cases_4320inst_101223_18/ca_5pfts_100523_0184.nc
# tmp file: tmp/CZ2_equilibrium_101723_0069.nc
#
#
# originl_file: /glade/u/home/adamhb/ahb_params/fates_api_25/ensembles/ca_5pfts_20cases_4320inst_101223_20/ca_5pfts_100523_0026.nc
# tmp file: tmp/CZ2_equilibrium_101723_0070.nc
#
#
# originl_file: /glade/u/home/adamhb/ahb_params/fates_api_25/ensembles/ca_5pfts_20cases_4320inst_101223_08/ca_5pfts_100523_0208.nc
# tmp file: tmp/CZ2_equilibrium_101723_0071.nc
#
#
# originl_file: /glade/u/home/adamhb/ahb_params/fates_api_25/ensembles/ca_5pfts_20cases_4320inst_101223_08/ca_5pfts_100523_0154.nc
# tmp file: tmp/CZ2_equilibrium_101723_0072.nc
#
#
# originl_file: /glade/u/home/adamhb/ahb_params/fates_api_25/ensembles/ca_5pfts_20cases_4320inst_101223_05/ca_5pfts_100523_0067.nc
# tmp file: tmp/CZ2_equilibrium_101723_0073.nc
#
#
# originl_file: /glade/u/home/adamhb/ahb_params/fates_api_25/ensembles/ca_5pfts_20cases_4320inst_101223_03/ca_5pfts_100523_0080.nc
# tmp file: tmp/CZ2_equilibrium_101723_0074.nc
#
#
# originl_file: /glade/u/home/adamhb/ahb_params/fates_api_25/ensembles/ca_5pfts_20cases_4320inst_101223_12/ca_5pfts_100523_0091.nc
# tmp file: tmp/CZ2_equilibrium_101723_0075.nc
#
#
# originl_file: /glade/u/home/adamhb/ahb_params/fates_api_25/ensembles/ca_5pfts_20cases_4320inst_101223_04/ca_5pfts_100523_0195.nc
# tmp file: tmp/CZ2_equilibrium_101723_0076.nc
#
#
# originl_file: /glade/u/home/adamhb/ahb_params/fates_api_25/ensembles/ca_5pfts_20cases_4320inst_101223_18/ca_5pfts_100523_0091.nc
# tmp file: tmp/CZ2_equilibrium_101723_0077.nc
#
#
# originl_file: /glade/u/home/adamhb/ahb_params/fates_api_25/ensembles/ca_5pfts_20cases_4320inst_101223_06/ca_5pfts_100523_0105.nc
# tmp file: tmp/CZ2_equilibrium_101723_0078.nc
#
#
# originl_file: /glade/u/home/adamhb/ahb_params/fates_api_25/ensembles/ca_5pfts_20cases_4320inst_101223_13/ca_5pfts_100523_0099.nc
# tmp file: tmp/CZ2_equilibrium_101723_0079.nc
#
#
# originl_file: /glade/u/home/adamhb/ahb_params/fates_api_25/ensembles/ca_5pfts_20cases_4320inst_101223_19/ca_5pfts_100523_0048.nc
# tmp file: tmp/CZ2_equilibrium_101723_0080.nc
#
#
# originl_file: /glade/u/home/adamhb/ahb_params/fates_api_25/ensembles/ca_5pfts_20cases_4320inst_101223_20/ca_5pfts_100523_0091.nc
# tmp file: tmp/CZ2_equilibrium_101723_0081.nc
#
#
# originl_file: /glade/u/home/adamhb/ahb_params/fates_api_25/ensembles/ca_5pfts_20cases_4320inst_101223_19/ca_5pfts_100523_0090.nc
# tmp file: tmp/CZ2_equilibrium_101723_0082.nc
#
#
# originl_file: /glade/u/home/adamhb/ahb_params/fates_api_25/ensembles/ca_5pfts_20cases_4320inst_101223_19/ca_5pfts_100523_0066.nc
# tmp file: tmp/CZ2_equilibrium_101723_0083.nc
#
#
# originl_file: /glade/u/home/adamhb/ahb_params/fates_api_25/ensembles/ca_5pfts_20cases_4320inst_101223_04/ca_5pfts_100523_0116.nc
# tmp file: tmp/CZ2_equilibrium_101723_0084.nc
#
#
# originl_file: /glade/u/home/adamhb/ahb_params/fates_api_25/ensembles/ca_5pfts_20cases_4320inst_101223_20/ca_5pfts_100523_0032.nc
# tmp file: tmp/CZ2_equilibrium_101723_0085.nc
#
#
# originl_file: /glade/u/home/adamhb/ahb_params/fates_api_25/ensembles/ca_5pfts_20cases_4320inst_101223_05/ca_5pfts_100523_0060.nc
# tmp file: tmp/CZ2_equilibrium_101723_0086.nc
#
#
# originl_file: /glade/u/home/adamhb/ahb_params/fates_api_25/ensembles/ca_5pfts_20cases_4320inst_101223_17/ca_5pfts_100523_0176.nc
# tmp file: tmp/CZ2_equilibrium_101723_0087.nc
#
#
# originl_file: /glade/u/home/adamhb/ahb_params/fates_api_25/ensembles/ca_5pfts_20cases_4320inst_101223_19/ca_5pfts_100523_0036.nc
# tmp file: tmp/CZ2_equilibrium_101723_0088.nc
#
#
# originl_file: /glade/u/home/adamhb/ahb_params/fates_api_25/ensembles/ca_5pfts_20cases_4320inst_101223_17/ca_5pfts_100523_0124.nc
# tmp file: tmp/CZ2_equilibrium_101723_0089.nc
#
#
# originl_file: /glade/u/home/adamhb/ahb_params/fates_api_25/ensembles/ca_5pfts_20cases_4320inst_101223_19/ca_5pfts_100523_0039.nc
# tmp file: tmp/CZ2_equilibrium_101723_0090.nc
#
#
# originl_file: /glade/u/home/adamhb/ahb_params/fates_api_25/ensembles/ca_5pfts_20cases_4320inst_101223_05/ca_5pfts_100523_0028.nc
# tmp file: tmp/CZ2_equilibrium_101723_0091.nc
#
#
# originl_file: /glade/u/home/adamhb/ahb_params/fates_api_25/ensembles/ca_5pfts_20cases_4320inst_101223_04/ca_5pfts_100523_0152.nc
# tmp file: tmp/CZ2_equilibrium_101723_0092.nc
#
#
# originl_file: /glade/u/home/adamhb/ahb_params/fates_api_25/ensembles/ca_5pfts_20cases_4320inst_101223_16/ca_5pfts_100523_0152.nc
# tmp file: tmp/CZ2_equilibrium_101723_0093.nc
#
#
# originl_file: /glade/u/home/adamhb/ahb_params/fates_api_25/ensembles/ca_5pfts_20cases_4320inst_101223_18/ca_5pfts_100523_0084.nc
# tmp file: tmp/CZ2_equilibrium_101723_0094.nc
#
#
# originl_file: /glade/u/home/adamhb/ahb_params/fates_api_25/ensembles/ca_5pfts_20cases_4320inst_101223_07/ca_5pfts_100523_0141.nc
# tmp file: tmp/CZ2_equilibrium_101723_0095.nc
#
#
# originl_file: /glade/u/home/adamhb/ahb_params/fates_api_25/ensembles/ca_5pfts_20cases_4320inst_101223_08/ca_5pfts_100523_0049.nc
# tmp file: tmp/CZ2_equilibrium_101723_0096.nc
#
#
# originl_file: /glade/u/home/adamhb/ahb_params/fates_api_25/ensembles/ca_5pfts_20cases_4320inst_101223_17/ca_5pfts_100523_0152.nc
# tmp file: tmp/CZ2_equilibrium_101723_0097.nc
#
#
# originl_file: /glade/u/home/adamhb/ahb_params/fates_api_25/ensembles/ca_5pfts_20cases_4320inst_101223_18/ca_5pfts_100523_0138.nc
# tmp file: tmp/CZ2_equilibrium_101723_0098.nc
#
#
# originl_file: /glade/u/home/adamhb/ahb_params/fates_api_25/ensembles/ca_5pfts_20cases_4320inst_101223_15/ca_5pfts_100523_0032.nc
# tmp file: tmp/CZ2_equilibrium_101723_0099.nc
#
#
# originl_file: /glade/u/home/adamhb/ahb_params/fates_api_25/ensembles/ca_5pfts_20cases_4320inst_101223_13/ca_5pfts_100523_0114.nc
# tmp file: tmp/CZ2_equilibrium_101723_0100.nc
#
#
# originl_file: /glade/u/home/adamhb/ahb_params/fates_api_25/ensembles/ca_5pfts_20cases_4320inst_101223_16/ca_5pfts_100523_0110.nc
# tmp file: tmp/CZ2_equilibrium_101723_0101.nc
#
#
# originl_file: /glade/u/home/adamhb/ahb_params/fates_api_25/ensembles/ca_5pfts_20cases_4320inst_101223_16/ca_5pfts_100523_0088.nc
# tmp file: tmp/CZ2_equilibrium_101723_0102.nc
#
#
# originl_file: /glade/u/home/adamhb/ahb_params/fates_api_25/ensembles/ca_5pfts_20cases_4320inst_101223_18/ca_5pfts_100523_0146.nc
# tmp file: tmp/CZ2_equilibrium_101723_0103.nc
#
#
# originl_file: /glade/u/home/adamhb/ahb_params/fates_api_25/ensembles/ca_5pfts_20cases_4320inst_101223_18/ca_5pfts_100523_0125.nc
# tmp file: tmp/CZ2_equilibrium_101723_0104.nc
#
#
# originl_file: /glade/u/home/adamhb/ahb_params/fates_api_25/ensembles/ca_5pfts_20cases_4320inst_101223_04/ca_5pfts_100523_0171.nc
# tmp file: tmp/CZ2_equilibrium_101723_0105.nc
#
#
# originl_file: /glade/u/home/adamhb/ahb_params/fates_api_25/ensembles/ca_5pfts_20cases_4320inst_101223_19/ca_5pfts_100523_0105.nc
# tmp file: tmp/CZ2_equilibrium_101723_0106.nc
#
#
# originl_file: /glade/u/home/adamhb/ahb_params/fates_api_25/ensembles/ca_5pfts_20cases_4320inst_101223_05/ca_5pfts_100523_0214.nc
# tmp file: tmp/CZ2_equilibrium_101723_0107.nc
#
#
# originl_file: /glade/u/home/adamhb/ahb_params/fates_api_25/ensembles/ca_5pfts_20cases_4320inst_101223_13/ca_5pfts_100523_0213.nc
# tmp file: tmp/CZ2_equilibrium_101723_0108.nc
#
#
# tmp_file: tmp/CZ2_equilibrium_101723_0001.nc
# destination: /glade/u/home/adamhb/ahb_params/fates_api_25/ensembles/CZ2_equilibrium_101723_01/CZ2_equilibrium_101723_0001.nc
# tmp_file: tmp/CZ2_equilibrium_101723_0002.nc
# destination: /glade/u/home/adamhb/ahb_params/fates_api_25/ensembles/CZ2_equilibrium_101723_01/CZ2_equilibrium_101723_0002.nc
# tmp_file: tmp/CZ2_equilibrium_101723_0003.nc
# destination: /glade/u/home/adamhb/ahb_params/fates_api_25/ensembles/CZ2_equilibrium_101723_01/CZ2_equilibrium_101723_0003.nc
# tmp_file: tmp/CZ2_equilibrium_101723_0004.nc
# destination: /glade/u/home/adamhb/ahb_params/fates_api_25/ensembles/CZ2_equilibrium_101723_01/CZ2_equilibrium_101723_0004.nc
# tmp_file: tmp/CZ2_equilibrium_101723_0005.nc
# destination: /glade/u/home/adamhb/ahb_params/fates_api_25/ensembles/CZ2_equilibrium_101723_01/CZ2_equilibrium_101723_0005.nc
# tmp_file: tmp/CZ2_equilibrium_101723_0006.nc
# destination: /glade/u/home/adamhb/ahb_params/fates_api_25/ensembles/CZ2_equilibrium_101723_01/CZ2_equilibrium_101723_0006.nc
# tmp_file: tmp/CZ2_equilibrium_101723_0007.nc
# destination: /glade/u/home/adamhb/ahb_params/fates_api_25/ensembles/CZ2_equilibrium_101723_01/CZ2_equilibrium_101723_0007.nc
# tmp_file: tmp/CZ2_equilibrium_101723_0008.nc
# destination: /glade/u/home/adamhb/ahb_params/fates_api_25/ensembles/CZ2_equilibrium_101723_01/CZ2_equilibrium_101723_0008.nc
# tmp_file: tmp/CZ2_equilibrium_101723_0009.nc
# destination: /glade/u/home/adamhb/ahb_params/fates_api_25/ensembles/CZ2_equilibrium_101723_01/CZ2_equilibrium_101723_0009.nc
# tmp_file: tmp/CZ2_equilibrium_101723_0010.nc
# destination: /glade/u/home/adamhb/ahb_params/fates_api_25/ensembles/CZ2_equilibrium_101723_01/CZ2_equilibrium_101723_0010.nc
# tmp_file: tmp/CZ2_equilibrium_101723_0011.nc
# destination: /glade/u/home/adamhb/ahb_params/fates_api_25/ensembles/CZ2_equilibrium_101723_01/CZ2_equilibrium_101723_0011.nc
# tmp_file: tmp/CZ2_equilibrium_101723_0012.nc
# destination: /glade/u/home/adamhb/ahb_params/fates_api_25/ensembles/CZ2_equilibrium_101723_01/CZ2_equilibrium_101723_0012.nc
# tmp_file: tmp/CZ2_equilibrium_101723_0013.nc
# destination: /glade/u/home/adamhb/ahb_params/fates_api_25/ensembles/CZ2_equilibrium_101723_01/CZ2_equilibrium_101723_0013.nc
# tmp_file: tmp/CZ2_equilibrium_101723_0014.nc
# destination: /glade/u/home/adamhb/ahb_params/fates_api_25/ensembles/CZ2_equilibrium_101723_01/CZ2_equilibrium_101723_0014.nc
# tmp_file: tmp/CZ2_equilibrium_101723_0015.nc
# destination: /glade/u/home/adamhb/ahb_params/fates_api_25/ensembles/CZ2_equilibrium_101723_01/CZ2_equilibrium_101723_0015.nc
# tmp_file: tmp/CZ2_equilibrium_101723_0016.nc
# destination: /glade/u/home/adamhb/ahb_params/fates_api_25/ensembles/CZ2_equilibrium_101723_01/CZ2_equilibrium_101723_0016.nc
# tmp_file: tmp/CZ2_equilibrium_101723_0017.nc
# destination: /glade/u/home/adamhb/ahb_params/fates_api_25/ensembles/CZ2_equilibrium_101723_01/CZ2_equilibrium_101723_0017.nc
# tmp_file: tmp/CZ2_equilibrium_101723_0018.nc
# destination: /glade/u/home/adamhb/ahb_params/fates_api_25/ensembles/CZ2_equilibrium_101723_01/CZ2_equilibrium_101723_0018.nc
# tmp_file: tmp/CZ2_equilibrium_101723_0019.nc
# destination: /glade/u/home/adamhb/ahb_params/fates_api_25/ensembles/CZ2_equilibrium_101723_01/CZ2_equilibrium_101723_0019.nc
# tmp_file: tmp/CZ2_equilibrium_101723_0020.nc
# destination: /glade/u/home/adamhb/ahb_params/fates_api_25/ensembles/CZ2_equilibrium_101723_01/CZ2_equilibrium_101723_0020.nc
# tmp_file: tmp/CZ2_equilibrium_101723_0021.nc
# destination: /glade/u/home/adamhb/ahb_params/fates_api_25/ensembles/CZ2_equilibrium_101723_01/CZ2_equilibrium_101723_0021.nc
# tmp_file: tmp/CZ2_equilibrium_101723_0022.nc
# destination: /glade/u/home/adamhb/ahb_params/fates_api_25/ensembles/CZ2_equilibrium_101723_01/CZ2_equilibrium_101723_0022.nc
# tmp_file: tmp/CZ2_equilibrium_101723_0023.nc
# destination: /glade/u/home/adamhb/ahb_params/fates_api_25/ensembles/CZ2_equilibrium_101723_01/CZ2_equilibrium_101723_0023.nc
# tmp_file: tmp/CZ2_equilibrium_101723_0024.nc
# destination: /glade/u/home/adamhb/ahb_params/fates_api_25/ensembles/CZ2_equilibrium_101723_01/CZ2_equilibrium_101723_0024.nc
# tmp_file: tmp/CZ2_equilibrium_101723_0025.nc
# destination: /glade/u/home/adamhb/ahb_params/fates_api_25/ensembles/CZ2_equilibrium_101723_01/CZ2_equilibrium_101723_0025.nc
# tmp_file: tmp/CZ2_equilibrium_101723_0026.nc
# destination: /glade/u/home/adamhb/ahb_params/fates_api_25/ensembles/CZ2_equilibrium_101723_01/CZ2_equilibrium_101723_0026.nc
# tmp_file: tmp/CZ2_equilibrium_101723_0027.nc
# destination: /glade/u/home/adamhb/ahb_params/fates_api_25/ensembles/CZ2_equilibrium_101723_01/CZ2_equilibrium_101723_0027.nc
# tmp_file: tmp/CZ2_equilibrium_101723_0028.nc
# destination: /glade/u/home/adamhb/ahb_params/fates_api_25/ensembles/CZ2_equilibrium_101723_01/CZ2_equilibrium_101723_0028.nc
# tmp_file: tmp/CZ2_equilibrium_101723_0029.nc
# destination: /glade/u/home/adamhb/ahb_params/fates_api_25/ensembles/CZ2_equilibrium_101723_01/CZ2_equilibrium_101723_0029.nc
# tmp_file: tmp/CZ2_equilibrium_101723_0030.nc
# destination: /glade/u/home/adamhb/ahb_params/fates_api_25/ensembles/CZ2_equilibrium_101723_01/CZ2_equilibrium_101723_0030.nc
# tmp_file: tmp/CZ2_equilibrium_101723_0031.nc
# destination: /glade/u/home/adamhb/ahb_params/fates_api_25/ensembles/CZ2_equilibrium_101723_01/CZ2_equilibrium_101723_0031.nc
# tmp_file: tmp/CZ2_equilibrium_101723_0032.nc
# destination: /glade/u/home/adamhb/ahb_params/fates_api_25/ensembles/CZ2_equilibrium_101723_01/CZ2_equilibrium_101723_0032.nc
# tmp_file: tmp/CZ2_equilibrium_101723_0033.nc
# destination: /glade/u/home/adamhb/ahb_params/fates_api_25/ensembles/CZ2_equilibrium_101723_01/CZ2_equilibrium_101723_0033.nc
# tmp_file: tmp/CZ2_equilibrium_101723_0034.nc
# destination: /glade/u/home/adamhb/ahb_params/fates_api_25/ensembles/CZ2_equilibrium_101723_01/CZ2_equilibrium_101723_0034.nc
# tmp_file: tmp/CZ2_equilibrium_101723_0035.nc
# destination: /glade/u/home/adamhb/ahb_params/fates_api_25/ensembles/CZ2_equilibrium_101723_01/CZ2_equilibrium_101723_0035.nc
# tmp_file: tmp/CZ2_equilibrium_101723_0036.nc
# destination: /glade/u/home/adamhb/ahb_params/fates_api_25/ensembles/CZ2_equilibrium_101723_01/CZ2_equilibrium_101723_0036.nc
# tmp_file: tmp/CZ2_equilibrium_101723_0037.nc
# destination: /glade/u/home/adamhb/ahb_params/fates_api_25/ensembles/CZ2_equilibrium_101723_02/CZ2_equilibrium_101723_0001.nc
# tmp_file: tmp/CZ2_equilibrium_101723_0038.nc
# destination: /glade/u/home/adamhb/ahb_params/fates_api_25/ensembles/CZ2_equilibrium_101723_02/CZ2_equilibrium_101723_0002.nc
# tmp_file: tmp/CZ2_equilibrium_101723_0039.nc
# destination: /glade/u/home/adamhb/ahb_params/fates_api_25/ensembles/CZ2_equilibrium_101723_02/CZ2_equilibrium_101723_0003.nc
# tmp_file: tmp/CZ2_equilibrium_101723_0040.nc
# destination: /glade/u/home/adamhb/ahb_params/fates_api_25/ensembles/CZ2_equilibrium_101723_02/CZ2_equilibrium_101723_0004.nc
# tmp_file: tmp/CZ2_equilibrium_101723_0041.nc
# destination: /glade/u/home/adamhb/ahb_params/fates_api_25/ensembles/CZ2_equilibrium_101723_02/CZ2_equilibrium_101723_0005.nc
# tmp_file: tmp/CZ2_equilibrium_101723_0042.nc
# destination: /glade/u/home/adamhb/ahb_params/fates_api_25/ensembles/CZ2_equilibrium_101723_02/CZ2_equilibrium_101723_0006.nc
# tmp_file: tmp/CZ2_equilibrium_101723_0043.nc
# destination: /glade/u/home/adamhb/ahb_params/fates_api_25/ensembles/CZ2_equilibrium_101723_02/CZ2_equilibrium_101723_0007.nc
# tmp_file: tmp/CZ2_equilibrium_101723_0044.nc
# destination: /glade/u/home/adamhb/ahb_params/fates_api_25/ensembles/CZ2_equilibrium_101723_02/CZ2_equilibrium_101723_0008.nc
# tmp_file: tmp/CZ2_equilibrium_101723_0045.nc
# destination: /glade/u/home/adamhb/ahb_params/fates_api_25/ensembles/CZ2_equilibrium_101723_02/CZ2_equilibrium_101723_0009.nc
# tmp_file: tmp/CZ2_equilibrium_101723_0046.nc
# destination: /glade/u/home/adamhb/ahb_params/fates_api_25/ensembles/CZ2_equilibrium_101723_02/CZ2_equilibrium_101723_0010.nc
# tmp_file: tmp/CZ2_equilibrium_101723_0047.nc
# destination: /glade/u/home/adamhb/ahb_params/fates_api_25/ensembles/CZ2_equilibrium_101723_02/CZ2_equilibrium_101723_0011.nc
# tmp_file: tmp/CZ2_equilibrium_101723_0048.nc
# destination: /glade/u/home/adamhb/ahb_params/fates_api_25/ensembles/CZ2_equilibrium_101723_02/CZ2_equilibrium_101723_0012.nc
# tmp_file: tmp/CZ2_equilibrium_101723_0049.nc
# destination: /glade/u/home/adamhb/ahb_params/fates_api_25/ensembles/CZ2_equilibrium_101723_02/CZ2_equilibrium_101723_0013.nc
# tmp_file: tmp/CZ2_equilibrium_101723_0050.nc
# destination: /glade/u/home/adamhb/ahb_params/fates_api_25/ensembles/CZ2_equilibrium_101723_02/CZ2_equilibrium_101723_0014.nc
# tmp_file: tmp/CZ2_equilibrium_101723_0051.nc
# destination: /glade/u/home/adamhb/ahb_params/fates_api_25/ensembles/CZ2_equilibrium_101723_02/CZ2_equilibrium_101723_0015.nc
# tmp_file: tmp/CZ2_equilibrium_101723_0052.nc
# destination: /glade/u/home/adamhb/ahb_params/fates_api_25/ensembles/CZ2_equilibrium_101723_02/CZ2_equilibrium_101723_0016.nc
# tmp_file: tmp/CZ2_equilibrium_101723_0053.nc
# destination: /glade/u/home/adamhb/ahb_params/fates_api_25/ensembles/CZ2_equilibrium_101723_02/CZ2_equilibrium_101723_0017.nc
# tmp_file: tmp/CZ2_equilibrium_101723_0054.nc
# destination: /glade/u/home/adamhb/ahb_params/fates_api_25/ensembles/CZ2_equilibrium_101723_02/CZ2_equilibrium_101723_0018.nc
# tmp_file: tmp/CZ2_equilibrium_101723_0055.nc
# destination: /glade/u/home/adamhb/ahb_params/fates_api_25/ensembles/CZ2_equilibrium_101723_02/CZ2_equilibrium_101723_0019.nc
# tmp_file: tmp/CZ2_equilibrium_101723_0056.nc
# destination: /glade/u/home/adamhb/ahb_params/fates_api_25/ensembles/CZ2_equilibrium_101723_02/CZ2_equilibrium_101723_0020.nc
# tmp_file: tmp/CZ2_equilibrium_101723_0057.nc
# destination: /glade/u/home/adamhb/ahb_params/fates_api_25/ensembles/CZ2_equilibrium_101723_02/CZ2_equilibrium_101723_0021.nc
# tmp_file: tmp/CZ2_equilibrium_101723_0058.nc
# destination: /glade/u/home/adamhb/ahb_params/fates_api_25/ensembles/CZ2_equilibrium_101723_02/CZ2_equilibrium_101723_0022.nc
# tmp_file: tmp/CZ2_equilibrium_101723_0059.nc
# destination: /glade/u/home/adamhb/ahb_params/fates_api_25/ensembles/CZ2_equilibrium_101723_02/CZ2_equilibrium_101723_0023.nc
# tmp_file: tmp/CZ2_equilibrium_101723_0060.nc
# destination: /glade/u/home/adamhb/ahb_params/fates_api_25/ensembles/CZ2_equilibrium_101723_02/CZ2_equilibrium_101723_0024.nc
# tmp_file: tmp/CZ2_equilibrium_101723_0061.nc
# destination: /glade/u/home/adamhb/ahb_params/fates_api_25/ensembles/CZ2_equilibrium_101723_02/CZ2_equilibrium_101723_0025.nc
# tmp_file: tmp/CZ2_equilibrium_101723_0062.nc
# destination: /glade/u/home/adamhb/ahb_params/fates_api_25/ensembles/CZ2_equilibrium_101723_02/CZ2_equilibrium_101723_0026.nc
# tmp_file: tmp/CZ2_equilibrium_101723_0063.nc
# destination: /glade/u/home/adamhb/ahb_params/fates_api_25/ensembles/CZ2_equilibrium_101723_02/CZ2_equilibrium_101723_0027.nc
# tmp_file: tmp/CZ2_equilibrium_101723_0064.nc
# destination: /glade/u/home/adamhb/ahb_params/fates_api_25/ensembles/CZ2_equilibrium_101723_02/CZ2_equilibrium_101723_0028.nc
# tmp_file: tmp/CZ2_equilibrium_101723_0065.nc
# destination: /glade/u/home/adamhb/ahb_params/fates_api_25/ensembles/CZ2_equilibrium_101723_02/CZ2_equilibrium_101723_0029.nc
# tmp_file: tmp/CZ2_equilibrium_101723_0066.nc
# destination: /glade/u/home/adamhb/ahb_params/fates_api_25/ensembles/CZ2_equilibrium_101723_02/CZ2_equilibrium_101723_0030.nc
# tmp_file: tmp/CZ2_equilibrium_101723_0067.nc
# destination: /glade/u/home/adamhb/ahb_params/fates_api_25/ensembles/CZ2_equilibrium_101723_02/CZ2_equilibrium_101723_0031.nc
# tmp_file: tmp/CZ2_equilibrium_101723_0068.nc
# destination: /glade/u/home/adamhb/ahb_params/fates_api_25/ensembles/CZ2_equilibrium_101723_02/CZ2_equilibrium_101723_0032.nc
# tmp_file: tmp/CZ2_equilibrium_101723_0069.nc
# destination: /glade/u/home/adamhb/ahb_params/fates_api_25/ensembles/CZ2_equilibrium_101723_02/CZ2_equilibrium_101723_0033.nc
# tmp_file: tmp/CZ2_equilibrium_101723_0070.nc
# destination: /glade/u/home/adamhb/ahb_params/fates_api_25/ensembles/CZ2_equilibrium_101723_02/CZ2_equilibrium_101723_0034.nc
# tmp_file: tmp/CZ2_equilibrium_101723_0071.nc
# destination: /glade/u/home/adamhb/ahb_params/fates_api_25/ensembles/CZ2_equilibrium_101723_02/CZ2_equilibrium_101723_0035.nc
# tmp_file: tmp/CZ2_equilibrium_101723_0072.nc
# destination: /glade/u/home/adamhb/ahb_params/fates_api_25/ensembles/CZ2_equilibrium_101723_02/CZ2_equilibrium_101723_0036.nc
# tmp_file: tmp/CZ2_equilibrium_101723_0073.nc
# destination: /glade/u/home/adamhb/ahb_params/fates_api_25/ensembles/CZ2_equilibrium_101723_03/CZ2_equilibrium_101723_0001.nc
# tmp_file: tmp/CZ2_equilibrium_101723_0074.nc
# destination: /glade/u/home/adamhb/ahb_params/fates_api_25/ensembles/CZ2_equilibrium_101723_03/CZ2_equilibrium_101723_0002.nc
# tmp_file: tmp/CZ2_equilibrium_101723_0075.nc
# destination: /glade/u/home/adamhb/ahb_params/fates_api_25/ensembles/CZ2_equilibrium_101723_03/CZ2_equilibrium_101723_0003.nc
# tmp_file: tmp/CZ2_equilibrium_101723_0076.nc
# destination: /glade/u/home/adamhb/ahb_params/fates_api_25/ensembles/CZ2_equilibrium_101723_03/CZ2_equilibrium_101723_0004.nc
# tmp_file: tmp/CZ2_equilibrium_101723_0077.nc
# destination: /glade/u/home/adamhb/ahb_params/fates_api_25/ensembles/CZ2_equilibrium_101723_03/CZ2_equilibrium_101723_0005.nc
# tmp_file: tmp/CZ2_equilibrium_101723_0078.nc
# destination: /glade/u/home/adamhb/ahb_params/fates_api_25/ensembles/CZ2_equilibrium_101723_03/CZ2_equilibrium_101723_0006.nc
# tmp_file: tmp/CZ2_equilibrium_101723_0079.nc
# destination: /glade/u/home/adamhb/ahb_params/fates_api_25/ensembles/CZ2_equilibrium_101723_03/CZ2_equilibrium_101723_0007.nc
# tmp_file: tmp/CZ2_equilibrium_101723_0080.nc
# destination: /glade/u/home/adamhb/ahb_params/fates_api_25/ensembles/CZ2_equilibrium_101723_03/CZ2_equilibrium_101723_0008.nc
# tmp_file: tmp/CZ2_equilibrium_101723_0081.nc
# destination: /glade/u/home/adamhb/ahb_params/fates_api_25/ensembles/CZ2_equilibrium_101723_03/CZ2_equilibrium_101723_0009.nc
# tmp_file: tmp/CZ2_equilibrium_101723_0082.nc
# destination: /glade/u/home/adamhb/ahb_params/fates_api_25/ensembles/CZ2_equilibrium_101723_03/CZ2_equilibrium_101723_0010.nc
# tmp_file: tmp/CZ2_equilibrium_101723_0083.nc
# destination: /glade/u/home/adamhb/ahb_params/fates_api_25/ensembles/CZ2_equilibrium_101723_03/CZ2_equilibrium_101723_0011.nc
# tmp_file: tmp/CZ2_equilibrium_101723_0084.nc
# destination: /glade/u/home/adamhb/ahb_params/fates_api_25/ensembles/CZ2_equilibrium_101723_03/CZ2_equilibrium_101723_0012.nc
# tmp_file: tmp/CZ2_equilibrium_101723_0085.nc
# destination: /glade/u/home/adamhb/ahb_params/fates_api_25/ensembles/CZ2_equilibrium_101723_03/CZ2_equilibrium_101723_0013.nc
# tmp_file: tmp/CZ2_equilibrium_101723_0086.nc
# destination: /glade/u/home/adamhb/ahb_params/fates_api_25/ensembles/CZ2_equilibrium_101723_03/CZ2_equilibrium_101723_0014.nc
# tmp_file: tmp/CZ2_equilibrium_101723_0087.nc
# destination: /glade/u/home/adamhb/ahb_params/fates_api_25/ensembles/CZ2_equilibrium_101723_03/CZ2_equilibrium_101723_0015.nc
# tmp_file: tmp/CZ2_equilibrium_101723_0088.nc
# destination: /glade/u/home/adamhb/ahb_params/fates_api_25/ensembles/CZ2_equilibrium_101723_03/CZ2_equilibrium_101723_0016.nc
# tmp_file: tmp/CZ2_equilibrium_101723_0089.nc
# destination: /glade/u/home/adamhb/ahb_params/fates_api_25/ensembles/CZ2_equilibrium_101723_03/CZ2_equilibrium_101723_0017.nc
# tmp_file: tmp/CZ2_equilibrium_101723_0090.nc
# destination: /glade/u/home/adamhb/ahb_params/fates_api_25/ensembles/CZ2_equilibrium_101723_03/CZ2_equilibrium_101723_0018.nc
# tmp_file: tmp/CZ2_equilibrium_101723_0091.nc
# destination: /glade/u/home/adamhb/ahb_params/fates_api_25/ensembles/CZ2_equilibrium_101723_03/CZ2_equilibrium_101723_0019.nc
# tmp_file: tmp/CZ2_equilibrium_101723_0092.nc
# destination: /glade/u/home/adamhb/ahb_params/fates_api_25/ensembles/CZ2_equilibrium_101723_03/CZ2_equilibrium_101723_0020.nc
# tmp_file: tmp/CZ2_equilibrium_101723_0093.nc
# destination: /glade/u/home/adamhb/ahb_params/fates_api_25/ensembles/CZ2_equilibrium_101723_03/CZ2_equilibrium_101723_0021.nc
# tmp_file: tmp/CZ2_equilibrium_101723_0094.nc
# destination: /glade/u/home/adamhb/ahb_params/fates_api_25/ensembles/CZ2_equilibrium_101723_03/CZ2_equilibrium_101723_0022.nc
# tmp_file: tmp/CZ2_equilibrium_101723_0095.nc
# destination: /glade/u/home/adamhb/ahb_params/fates_api_25/ensembles/CZ2_equilibrium_101723_03/CZ2_equilibrium_101723_0023.nc
# tmp_file: tmp/CZ2_equilibrium_101723_0096.nc
# destination: /glade/u/home/adamhb/ahb_params/fates_api_25/ensembles/CZ2_equilibrium_101723_03/CZ2_equilibrium_101723_0024.nc
# tmp_file: tmp/CZ2_equilibrium_101723_0097.nc
# destination: /glade/u/home/adamhb/ahb_params/fates_api_25/ensembles/CZ2_equilibrium_101723_03/CZ2_equilibrium_101723_0025.nc
# tmp_file: tmp/CZ2_equilibrium_101723_0098.nc
# destination: /glade/u/home/adamhb/ahb_params/fates_api_25/ensembles/CZ2_equilibrium_101723_03/CZ2_equilibrium_101723_0026.nc
# tmp_file: tmp/CZ2_equilibrium_101723_0099.nc
# destination: /glade/u/home/adamhb/ahb_params/fates_api_25/ensembles/CZ2_equilibrium_101723_03/CZ2_equilibrium_101723_0027.nc
# tmp_file: tmp/CZ2_equilibrium_101723_0100.nc
# destination: /glade/u/home/adamhb/ahb_params/fates_api_25/ensembles/CZ2_equilibrium_101723_03/CZ2_equilibrium_101723_0028.nc
# tmp_file: tmp/CZ2_equilibrium_101723_0101.nc
# destination: /glade/u/home/adamhb/ahb_params/fates_api_25/ensembles/CZ2_equilibrium_101723_03/CZ2_equilibrium_101723_0029.nc
# tmp_file: tmp/CZ2_equilibrium_101723_0102.nc
# destination: /glade/u/home/adamhb/ahb_params/fates_api_25/ensembles/CZ2_equilibrium_101723_03/CZ2_equilibrium_101723_0030.nc
# tmp_file: tmp/CZ2_equilibrium_101723_0103.nc
# destination: /glade/u/home/adamhb/ahb_params/fates_api_25/ensembles/CZ2_equilibrium_101723_03/CZ2_equilibrium_101723_0031.nc
# tmp_file: tmp/CZ2_equilibrium_101723_0104.nc
# destination: /glade/u/home/adamhb/ahb_params/fates_api_25/ensembles/CZ2_equilibrium_101723_03/CZ2_equilibrium_101723_0032.nc
# tmp_file: tmp/CZ2_equilibrium_101723_0105.nc
# destination: /glade/u/home/adamhb/ahb_params/fates_api_25/ensembles/CZ2_equilibrium_101723_03/CZ2_equilibrium_101723_0033.nc
# tmp_file: tmp/CZ2_equilibrium_101723_0106.nc
# destination: /glade/u/home/adamhb/ahb_params/fates_api_25/ensembles/CZ2_equilibrium_101723_03/CZ2_equilibrium_101723_0034.nc
# tmp_file: tmp/CZ2_equilibrium_101723_0107.nc
# destination: /glade/u/home/adamhb/ahb_params/fates_api_25/ensembles/CZ2_equilibrium_101723_03/CZ2_equilibrium_101723_0035.nc
# tmp_file: tmp/CZ2_equilibrium_101723_0108.nc
# destination: /glade/u/home/adamhb/ahb_params/fates_api_25/ensembles/CZ2_equilibrium_101723_03/CZ2_equilibrium_101723_0036.nc
